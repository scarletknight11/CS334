# %%
if __name__ == '__main__':
    import imageio
    import matplotlib.pyplot as plt
    # %matplotlib inline

    pic = imageio.imread('D:/CS334/ireland-03gray.tif')
    plt.figure(figsize = (10, 10))

    plt.imshow(pic)

# %%
print('Type of the image : ' , type(pic))
print()
print('Shape of the image : {}'.format(pic.shape))
print('Image Hight {}'.format(pic.shape[0]))
print('Image Width {}'.format(pic.shape[1]))
print('Dimension of Image {}'.format(pic.ndim))
# Out:
# Type of the image :  <class 'imageio.core.util.Array'>
#
# Shape of the image : (1200, 1600)
# Image Hight 1200
# Image Width 1600
# Dimension of Image 2

# %%
print('Image size {}'.format(pic.size))
print('Maximum RGB value in this image {}'.format(pic.max()))
print('Minimum RGB value in this image {}'.format(pic.min()))
# Out:
# Image size 1920000
# Maximum RGB value in this image 255
# Minimum RGB value in this image 0

# %%
pic = imageio.imread('C:/Users/sanji/Pictures/demo_2.jpg')

pic[:30 , :, 0] = 250 # full intensity to those pixel's R channel
plt.figure( figsize = (10,10))
plt.imshow(pic)
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('C:/Users/sanji/Pictures/blackandwhite.jpg',0)

laplacian = cv2.Laplacian(img, cv2.CV_64F)
sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)

plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
import cv2, matplotlib
import numpy as np
import matplotlib.pyplot as plt
